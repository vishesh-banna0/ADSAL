# %% [markdown]
# <a href="https://colab.research.google.com/github/vishesh-banna0/ADSAL/blob/main/adsa_assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Write a program to reverse a singly linked list (implement both iterative and recursive methods).

# %%
# %%writefile reverseList.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct node {
#     int data;
#     struct node *next;
# };
#
# // function to create a node
#
# struct node* createNode(int data) {
#     struct node* newNode = (struct node*)malloc(sizeof(struct node));
#     newNode->data = data;
#     newNode->next = NULL;
#     return newNode;
# }
#
# // Simple insert function that inserts at the end
#
# struct node* insert(struct node* head, int data) {
#     struct node* newNode = createNode(data);
#
#
#     if (head == NULL)
#         return newNode;
#
#     struct node* temp = head;
#     while (temp->next != NULL)
#         temp = temp->next;
#
#     temp->next = newNode;
#     return head;
# }
#
#
# // Function to print the linked list
#
# void printList(struct node* head) {
#     struct node* temp = head;
#     while (temp != NULL) {
#         printf("%d -> ", temp->data);
#         temp = temp->next;
#     }
#     printf("NULL\n");
# }
#
# struct node* reverseList(struct node* head) {
#
#     if (head == NULL || head->next == NULL)
#         return head;
#
#
#     struct node* newHead = reverseList(head->next);
#
#
#     head->next->next = head;
#     head->next = NULL;
#
#
#     return newHead;
# }
#
#
#
#
# int main() {
#     struct node* head = NULL;
#
#     head = insert(head, 10);
#     head = insert(head, 20);
#     head = insert(head, 30);
#     head = insert(head, 40);
#     head = insert(head, 50);
#     head = insert(head, 60);
#
#     printf("Original Linked List: ");
#     printList(head);
#
#     struct node* reversedHead = NULL;
#     struct node* current = head;
#     struct node* prev = NULL;
#     struct node* next = NULL;
#
#     while (current != NULL) {
#         next = current->next;
#         current->next = prev;
#         prev = current;
#         current = next;
#     }
#
#     reversedHead = prev;
#
#     printf("Reversed Linked List (Iterative): ");
#     printList(reversedHead);
#
#
#     struct node* head1 = NULL;
#     head1 = insert(head1, 10);
#     head1 = insert(head1, 20);
#     head1 = insert(head1, 30);
#     head1 = insert(head1, 40);
#     head1 = insert(head1, 50);
#     head1 = insert(head1, 60);
#
#
#     printf("Reversing list with recursion: ");
#     struct node* recurseHead = reverseList(head1);
#     printList(recurseHead);
#
#
#
#
#
#     return 0;
# }
# Out:
# Overwriting reverseList.c

# %%
! gcc reverseList.c -o reverseList
# !chmod +x reverseList
# !./reverseList
# Out:
# Original Linked List: 10 -> 20 -> 30 -> 40 -> 50 -> 60 -> NULL
# Reversed Linked List (Iterative): 60 -> 50 -> 40 -> 30 -> 20 -> 10 -> NULL
# Reversing list with recursion: 60 -> 50 -> 40 -> 30 -> 20 -> 10 -> NULL

# %% [markdown]
# 2. Write a program to search for a given element in a linked list and print its position.

# %%
# %%writefile searchList.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct node {
#     int data;
#     struct node *next;
# };
#
# // function to create a node
#
# struct node* createNode(int data) {
#     struct node* newNode = (struct node*)malloc(sizeof(struct node));
#     newNode->data = data;
#     newNode->next = NULL;
#     return newNode;
# }
#
# // Simple insert function that inserts at the end
#
# struct node* insert(struct node* head, int data) {
#     struct node* newNode = createNode(data);
#
#
#     if (head == NULL)
#         return newNode;
#
#     struct node* temp = head;
#     while (temp->next != NULL)
#         temp = temp->next;
#
#     temp->next = newNode;
#     return head;
# }
#
#
# // Function to print the linked list
#
# void printList(struct node* head) {
#     struct node* temp = head;
#     while (temp != NULL) {
#         printf("%d -> ", temp->data);
#         temp = temp->next;
#     }
#     printf("NULL\n");
# }
#
# int searchList(struct node* head, int target) {
#     int position = 1;
#     struct node* current = head;
#
#     while (current != NULL) {
#         if (current->data == target) {
#             return position;
#         }
#         current = current->next;
#         position++;
#     }
#
#     return -1;
# }
#
# int main(){
#
#   struct node* head = NULL;
#
#     head = insert(head, 10);
#     head = insert(head, 20);
#     head = insert(head, 30);
#     head = insert(head, 40);
#     head = insert(head, 50);
#     head = insert(head, 60);
#
#     printf("Original Linked List: ");
#     printList(head);
#
#     int target = 30;
#     int position = searchList(head, target);
#
#     if (position != -1) {
#         printf("Element %d found at position %d\n", target, position);
#         } else {
#         printf("Element %d not found in the list\n", target);
#     }
#
#     return 0;
# }
# Out:
# Overwriting searchList.c

# %%
# !gcc searchList.c -o searchList
# !chmod +x searchList
# !./searchList
# Out:
# Original Linked List: 10 -> 20 -> 30 -> 40 -> 50 -> 60 -> NULL
# Element 30 found at position 3

# %% [markdown]
# 3. Create a singly linked list of n nodes and display all its elements.

# %%
# %%writefile create.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct node {
#     int data;
#     struct node *next;
# };
#
# struct node* createNode(int data) {
#     struct node* newNode = (struct node*)malloc(sizeof(struct node));
#     newNode->data = data;
#     newNode->next = NULL;
#     return newNode;
# }
#
# // Simple insert function that inserts at the end
#
# struct node* insert(struct node* head, int data) {
#     struct node* newNode = createNode(data);
#
#
#     if (head == NULL)
#         return newNode;
#
#     struct node* temp = head;
#     while (temp->next != NULL)
#         temp = temp->next;
#
#     temp->next = newNode;
#     return head;
# }
#
#
# // Function to print the linked list
#
# void printList(struct node* head) {
#     struct node* temp = head;
#     while (temp != NULL) {
#         printf("%d -> ", temp->data);
#         temp = temp->next;
#     }
#     printf("NULL\n");
# }
#
# int main(){
#     struct node* head = NULL;
#     int n;
#     printf("Enter the number of nodes: ");
#     scanf("%d", &n);
#
#     for (int i = 0; i < n; i++) {
#         int data;
#         printf("Enter data for node %d: ", i + 1);
#         scanf("%d", &data);
#         head = insert(head, data);
#     }
#
#     printf("Linked List: ");
#     printList(head);
#
# }
# Out:
# Overwriting create.c

# %%
# !gcc create.c -o create
# !chmod +x create
# !./create
# Out:
# Enter the number of nodes: 5
# Enter data for node 1: 5
# Enter data for node 2: 6
# Enter data for node 3: 7
# Enter data for node 4: 11
# Enter data for node 5: 5
# Linked List: 5 -> 6 -> 7 -> 11 -> 5 -> NULL

# %% [markdown]
# 4. Write a program to detect whether a linked list contains a loop using Floyd’s Cycle Detection
# Algorithm.

# %%
# %%writefile scanCycle.c
# #include<stdio.h>
# #include<stdlib.h>
#
# struct node {
#     int data;
#     struct node *next;
# };
#
# struct node* createNode(int data) {
#     struct node* newNode = (struct node*)malloc(sizeof(struct node));
#     newNode->data = data;
#     newNode->next = NULL;
#     return newNode;
# }
#
# // Simple insert function that inserts at the end
#
# struct node* insert(struct node* head, int data) {
#     struct node* newNode = createNode(data);
#
#
#     if (head == NULL)
#         return newNode;
#
#     struct node* temp = head;
#     while (temp->next != NULL)
#         temp = temp->next;
#
#     temp->next = newNode;
#     return head;
# }
#
#
# // Function to print the linked list
#
# void printList(struct node* head) {
#     struct node* temp = head;
#     while (temp != NULL) {
#         printf("%d -> ", temp->data);
#         temp = temp->next;
#     }
#     printf("NULL\n");
# }
#
# int detectCycle(struct node* head) {
#     struct node* slow = head;
#     struct node* fast = head;
#     while (fast != NULL && fast->next != NULL) {
#         slow = slow->next;
#         fast = fast->next->next;
#         if (slow == fast) {
#             return 1;
#         }
#     }
#     return 0;
# }
#
# int main() {
#     struct node* head = NULL;
#
#     head = insert(head, 10);
#     head = insert(head, 20);
#     head = insert(head, 30);
#     head = insert(head, 40);
#     head = insert(head, 50);
#     head = insert(head, 60);
#
#     struct node* head_next = head->next; // Declare head_next
#     head->next->next->next->next->next->next = head_next;
#
#     int hasCycle = detectCycle(head);
#
#     if (hasCycle) {
#         printf("The linked list contains a loop.\n");
#     } else {
#         printf("The linked list does not contain a loop.\n");
#     }
#
#
#
#     return 0;
# }
# Out:
# Overwriting scanCycle.c

# %%
# !gcc scanCycle.c -o scanCycle
# !chmod +x scanCycle
# !./scanCycle
# Out:
# The linked list contains a loop.

# %% [markdown]
# 5. Implement insertion operations in a singly linked list to insert a node:
# * At the beginning
# * At the end
# * At a given position

# %%
# %%writefile insertion.c
# #include <stdio.h>
# #include <stdlib.h>
# #include <stddef.h>
#
# struct node {
#     int data;
#     struct node *next;
# };
#
# struct node* createNode(int data) {
#     struct node* newNode = (struct node*)malloc(sizeof(struct node));
#     newNode->data = data;
#     newNode->next = NULL;
#     return newNode;
# }
#
# // Simple insert function that inserts at the end
#
# struct node* insert(struct node* head, int data) {
#     struct node* newNode = createNode(data);
#
#
#     if (head == NULL)
#         return newNode;
#
#     struct node* temp = head;
#     while (temp->next != NULL)
#         temp = temp->next;
#
#     temp->next = newNode;
#     return head;
# }
#
#
# // Function to print the linked list
#
# void printList(struct node* head) {
#     struct node* temp = head;
#     while (temp != NULL) {
#         printf("%d -> ", temp->data);
#         temp = temp->next;
#     }
#     printf("NULL\n");
# }
#
# struct node* insert_at_end(struct node* head, int data) {
#     struct node* newNode = createNode(data);
#     if (head == NULL) {
#         return newNode;
#     }
#     struct node* temp = head;
#     while (temp->next != NULL) {
#         temp = temp->next;
#     }
#     temp->next = newNode;
#     return head;
# }
#
# struct node* insert_at_beginning(struct node* head, int data) {
#     struct node* newNode = createNode(data);
#     newNode->next = head;
#     return newNode;
# }
#
# struct node* insert_at_position(struct node* head, int data, int position) {
#     if (position < 1) {
#         printf("Position should be 1 or greater\n");
#         return head;
#     }
#     if (position == 1) {
#         return insert_at_beginning(head, data);
#     }
#     struct node* newNode = createNode(data);
#     struct node* temp = head;
#     for (int i = 1; i < position - 1; i++) {
#         if (temp == NULL) {
#              printf("Invalid position\n");
#             return head;
#         }
#         temp = temp->next;
#
#     }
#      if (temp == NULL) {
#          printf("Invalid position\n");
#          return head;
#      }
#     newNode->next = temp->next;
#     temp->next = newNode;
#     return head;
# }
#
# int main() {
#     struct node* head = NULL;
#     int n;
#     printf("Enter the number of nodes: ");
#     scanf("%d", &n);
#     for (int i = 0; i < n; i++) {
#         int data;
#         printf("Enter data for node %d: ", i + 1);
#         scanf("%d", &data);
#         head = insert(head, data);
#     }
#     printf("Original Linked List: ");
#     printList(head);
#     int data, position;
#     printf("Enter data to insert at the end: ");
#     scanf("%d", &data);
#     head = insert_at_end(head, data);
#     printf("Linked List after inserting at the end: ");
#     printList(head);
#     printf("Enter data to insert at the beginning: ");
#     scanf("%d", &data);
#     head = insert_at_beginning(head, data);
#     printf("Linked List after inserting at the beginning: ");
#     printList(head);
#     printf("Enter data and position to insert: ");
#     scanf("%d %d", &data, &position);
#     head = insert_at_position(head, data, position);
#     printf("Linked List after inserting at position %d: ", position);
#     printList(head);
#     return 0;
# }
# Out:
# Overwriting insertion.c

# %%
# !gcc insertion.c -o insertion
# !chmod +x insertion
# !./insertion
# Out:
# Enter the number of nodes: 5
# Enter data for node 1: 10
# Enter data for node 2: 20
# Enter data for node 3: 30
# Enter data for node 4: 40
# Enter data for node 5: 50
# Original Linked List: 10 -> 20 -> 30 -> 40 -> 50 -> NULL
# Enter data to insert at the end: 1
# Linked List after inserting at the end: 10 -> 20 -> 30 -> 40 -> 50 -> 1 -> NULL
# Enter data to insert at the beginning: 5
# Linked List after inserting at the beginning: 5 -> 10 -> 20 -> 30 -> 40 -> 50 -> 1 -> NULL
# Enter data and position to insert: 3
# 7
# Linked List after inserting at position 7: 5 -> 10 -> 20 -> 30 -> 40 -> 50 -> 3 -> 1 -> NULL

# %% [markdown]
# 6. Write a program to count and display the total number of nodes present in a linked list.

# %%
# %%writefile count.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node {
#     int data;
#     struct Node* next;
# };
#
# void printList(struct Node* node) {
#     while (node != NULL) {
#         printf("%d -> ", node->data);
#         node = node->next;
#     }
#     printf("NULL\n");
# }
#
# void append(struct Node** head_ref, int new_data) {
#     struct Node* new_node = (struct Node*)malloc(sizeof(struct Node));
#     struct Node* last = *head_ref;
#     new_node->data = new_data;
#     new_node->next = NULL;
#     if (*head_ref == NULL) {
#         *head_ref = new_node;
#         return;
#     }
#     while (last->next != NULL) {
#         last = last->next;
#     }
#     last->next = new_node;
# }
#
# void countNodes(struct Node* head) {
#     int count = 0;
#     struct Node* current = head;
#     while (current != NULL) {
#         count++;
#         current = current->next;
#     }
#     printf("Total number of nodes: %d\n", count);
# }
#
# int main() {
#     struct Node* head = NULL;
#     append(&head, 100);
#     append(&head, 200);
#     append(&head, 300);
#     append(&head, 400);
#
#     printf("Current list: ");
#     printList(head);
#
#     countNodes(head);
#
#     return 0;
# }
# Out:
# Overwriting count.c

# %%
# !gcc count.c -o count
# !chmod +x count
# !./count
# Out:
# Current list: 100 -> 200 -> 300 -> 400 -> NULL
# Total number of nodes: 4

# %% [markdown]
# 7. Write a program to merge two sorted linked lists into one sorted linked list.

# %%
# %%writefile merge.c
#
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node {
#     int data;
#     struct Node* next;
# };
#
# void printList(struct Node* node) {
#     while (node != NULL) {
#         printf("%d -> ", node->data);
#         node = node->next;
#     }
#     printf("NULL\n");
# }
#
# void append(struct Node** head_ref, int new_data) {
#     struct Node* new_node = (struct Node*)malloc(sizeof(struct Node));
#     struct Node* last = *head_ref;
#     new_node->data = new_data;
#     new_node->next = NULL;
#     if (*head_ref == NULL) {
#         *head_ref = new_node;
#         return;
#     }
#     while (last->next != NULL) {
#         last = last->next;
#     }
#     last->next = new_node;
# }
#
# // Function to merge two sorted lists
# struct Node* mergeSortedLists(struct Node* l1, struct Node* l2) {
#     // Create a dummy node to act as the start of the new list
#     struct Node dummy;
#     struct Node* tail = &dummy;
#     dummy.next = NULL;
#
#     while (l1 != NULL && l2 != NULL) {
#         if (l1->data <= l2->data) {
#             tail->next = l1;
#             l1 = l1->next;
#         } else {
#             tail->next = l2;
#             l2 = l2->next;
#         }
#         tail = tail->next;
#     }
#
#     // Attach the remaining part of the non-empty list
#     if (l1 != NULL) {
#         tail->next = l1;
#     } else {
#         tail->next = l2;
#     }
#
#     return dummy.next;
# }
#
# int main() {
#     struct Node* list1 = NULL;
#     append(&list1, 5);
#     append(&list1, 10);
#     append(&list1, 15);
#
#     struct Node* list2 = NULL;
#     append(&list2, 2);
#     append(&list2, 3);
#     append(&list2, 20);
#
#     printf("List 1: ");
#     printList(list1);
#     printf("List 2: ");
#     printList(list2);
#
#     struct Node* merged_head = mergeSortedLists(list1, list2);
#
#     printf("Merged Sorted List: ");
#     printList(merged_head);
#
#     return 0;
# }
# Out:
# Overwriting merge.c

# %%
# !gcc merge.c -o merge
# !chmod +x merge
# !./merge
# Out:
# List 1: 5 -> 10 -> 15 -> NULL
# List 2: 2 -> 3 -> 20 -> NULL
# Merged Sorted List: 2 -> 3 -> 5 -> 10 -> 15 -> 20 -> NULL

# %% [markdown]
# 8. Delete nodes from a singly linked list from:
# * The beginning
# * The end
# * A given position

# %%
# %%writefile delete.c
#
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node {
#     int data;
#     struct Node* next;
# };
#
# void printList(struct Node* node) {
#     while (node != NULL) {
#         printf("%d -> ", node->data);
#         node = node->next;
#     }
#     printf("NULL\n");
# }
#
# void append(struct Node** head_ref, int new_data) {
#     struct Node* new_node = (struct Node*)malloc(sizeof(struct Node));
#     struct Node* last = *head_ref;
#     new_node->data = new_data;
#     new_node->next = NULL;
#     if (*head_ref == NULL) {
#         *head_ref = new_node;
#         return;
#     }
#     while (last->next != NULL) {
#         last = last->next;
#     }
#     last->next = new_node;
# }
#
# void deleteFromBeginning(struct Node** head_ref) {
#     if (*head_ref == NULL) return;
#     struct Node* temp = *head_ref;
#     *head_ref = (*head_ref)->next;
#     free(temp);
# }
#
# void deleteFromEnd(struct Node** head_ref) {
#     if (*head_ref == NULL) return; // List is empty
#
#     if ((*head_ref)->next == NULL) {
#         free(*head_ref);
#         *head_ref = NULL;
#         return;
#     }
#
#     struct Node* second_last = *head_ref;
#     while (second_last->next->next != NULL) {
#         second_last = second_last->next;
#     }
#
#     free(second_last->next); // Free the last node
#     second_last->next = NULL;  // Set new end
# }
#
# void deleteFromPosition(struct Node** head_ref, int position) {
#     if (*head_ref == NULL) return; // List is empty
#
#     struct Node* temp = *head_ref;
#
#     // If head needs to be removed
#     if (position == 1) {
#         *head_ref = temp->next;
#         free(temp);
#         return;
#     }
#
#     // Find the node just before the one to be deleted
#     for (int i = 1; temp != NULL && i < position - 1; i++) {
#         temp = temp->next;
#     }
#
#     // If position is out of bounds
#     if (temp == NULL || temp->next == NULL) return;
#
#     struct Node* node_to_delete = temp->next;
#     temp->next = node_to_delete->next; // Unlink the node
#     free(node_to_delete);            // Free memory
# }
#
# int main() {
#     struct Node* head = NULL;
#     append(&head, 1);
#     append(&head, 2);
#     append(&head, 3);
#     append(&head, 4);
#     append(&head, 5);
#
#     printf("Original List:           ");
#     printList(head);
#
#     deleteFromBeginning(&head);
#     printf("After deleting beginning:  ");
#     printList(head);
#
#     deleteFromEnd(&head);
#     printf("After deleting end:        ");
#     printList(head);
#
#     deleteFromPosition(&head, 2); // Deleting '3'
#     printf("After deleting position 2: ");
#     printList(head);
#
#     return 0;
# }
# Out:
# Overwriting delete.c

# %%
# !gcc delete.c -o delete
# !chmod +x delete
# !./delete
# Out:
# Original List:           1 -> 2 -> 3 -> 4 -> 5 -> NULL
# After deleting beginning:  2 -> 3 -> 4 -> 5 -> NULL
# After deleting end:        2 -> 3 -> 4 -> NULL
# After deleting position 2: 2 -> 4 -> NULL

# %% [markdown]
# 9. Find and print the middle element of a linked list using the two-pointer technique.

# %%
# %%writefile point.c
# #include <stdio.h>
# #include <stdlib.h>
# #include <stddef.h>
#
# struct Node {
#     int data;
#     struct Node* next;
# };
#
# void printList(struct Node* node) {
#     while (node != NULL) {
#         printf("%d -> ", node->data);
#         node = node->next;
#     }
#     printf("NULL\n");
# }
#
# void append(struct Node** head_ref, int new_data) {
#     struct Node* new_node = (struct Node*)malloc(sizeof(struct Node));
#     struct Node* last = *head_ref;
#     new_node->data = new_data;
#     new_node->next = NULL;
#     if (*head_ref == NULL) {
#         *head_ref = new_node;
#         return;
#     }
#     while (last->next != NULL) {
#         last = last->next;
#     }
#     last->next = new_node;
# }
#
# // Function to find the middle element
# void findMiddleElement(struct Node* head) {
#     struct Node *slow_ptr = head;
#     struct Node *fast_ptr = head;
#
#     if (head != NULL) {
#         while (fast_ptr != NULL && fast_ptr->next != NULL) {
#             fast_ptr = fast_ptr->next->next;
#             slow_ptr = slow_ptr->next;
#         }
#         printf("The middle element is: %d\n", slow_ptr->data);
#     } else {
#         printf("The list is empty.\n");
#     }
# }
#
# int main() {
#
#     // Test Case 1: Odd number of nodes
#
#     struct Node* head_odd = NULL;
#     append(&head_odd, 1);
#     append(&head_odd, 2);
#     append(&head_odd, 3);
#     append(&head_odd, 4);
#     append(&head_odd, 5);
#     printf("List with odd nodes: ");
#     printList(head_odd);
#     findMiddleElement(head_odd);
#
#     printf("\n");
#
#     // Test Case 2: Even number of nodes
#     struct Node* head_even = NULL;
#     append(&head_even, 1);
#     append(&head_even, 2);
#     append(&head_even, 3);
#     append(&head_even, 4);
#     append(&head_even, 5);
#     append(&head_even, 6);
#     printf("List with even nodes: ");
#     printList(head_even);
#     findMiddleElement(head_even);
#
#     return 0;
# }
# Out:
# Overwriting point.c

# %%
# !gcc point.c -o point
# !chmod +x point
# !./point
# Out:
# List with odd nodes: 1 -> 2 -> 3 -> 4 -> 5 -> NULL
# The middle element is: 3
#
# List with even nodes: 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> NULL
# The middle element is: 4

# %% [markdown]
# 10. Remove duplicate elements from a sorted linked list so that each element appears only once.

# %%
# %%writefile sort.c
# #include <stdio.h>
# #include <stdlib.h>
# #include <stddef.h>
#
# struct Node {
#     int data;
#     struct Node* next;
# };
#
# void printList(struct Node* node) {
#     while (node != NULL) {
#         printf("%d -> ", node->data);
#         node = node->next;
#     }
#     printf("NULL\n");
# }
#
# void append(struct Node** head_ref, int new_data) {
#     struct Node* new_node = (struct Node*)malloc(sizeof(struct Node));
#     struct Node* last = *head_ref;
#     new_node->data = new_data;
#     new_node->next = NULL;
#     if (*head_ref == NULL) {
#         *head_ref = new_node;
#         return;
#     }
#     while (last->next != NULL) {
#         last = last->next;
#     }
#     last->next = new_node;
# }
#
#
# // Function to remove duplicates from a sorted list
# void removeDuplicates(struct Node* head) {
#     struct Node* current = head;
#
#     if (current == NULL) return;
#
#     while (current->next != NULL) {
#
#         // Compare current node's data with the next node's data
#         if (current->data == current->next->data) {
#             struct Node* node_to_delete = current->next;
#             current->next = current->next->next;
#             free(node_to_delete);
#         } else {
#
#             // Only move to the next node if no duplicate was found
#             current = current->next;
#         }
#     }
# }
#
# int main() {
#     struct Node* head = NULL;
#
#     // Create a sorted list with duplicates
#     append(&head, 11);
#     append(&head, 11);
#     append(&head, 21);
#     append(&head, 43);
#     append(&head, 43);
#     append(&head, 60);
#
#     printf("Original list with duplicates: ");
#     printList(head);
#
#     removeDuplicates(head);
#
#     printf("List after removing duplicates: ");
#     printList(head);
#
#     return 0;
# }
# Out:
# Overwriting sort.c

# %%
# !gcc sort.c -o sort
# !chmod +x sort
# !./sort
# Out:
# Original list with duplicates: 11 -> 11 -> 21 -> 43 -> 43 -> 60 -> NULL
# List after removing duplicates: 11 -> 21 -> 43 -> 60 -> NULL
